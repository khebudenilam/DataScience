# %%
import pandas as pd
from sklearn.ensemble import RandomForestRegressor,RandomForestClassifier
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_absolute_error,accuracy_score

# %%
A=pd.read_csv("E:/Python/Dataset/Cars93.csv")

# %%
A.head()
# Out:
#    Unnamed: 0 Manufacturer    Model     Type  Min.Price  Price  Max.Price  \
# 0           1        Acura  Integra    Small       12.9   15.9       18.8
# 1           2        Acura   Legend  Midsize       29.2   33.9       38.7
# 2           3         Audi       90  Compact       25.9   29.1       32.3
# 3           4         Audi      100  Midsize       30.8   37.7       44.6
# 4           5          BMW     535i  Midsize       23.7   30.0       36.2
#
#    MPG.city  MPG.highway             AirBags  ... Passengers Length  \
# 0        25           31                None  ...          5    177
# 1        18           25               Front  ...        195    115
# 2        20           26               Front  ...        180    102
# 3        19           26  Driver & Passenger  ...          6    193
# 4        22           30         Driver only  ...          4    186
#
#    Wheelbase  Width  Turn.circle Rear.seat.room Luggage.room  Weight  \
# ...

# %%
Y=A[["Weight"]]
X=A.drop(labels=["Weight","Unnamed: 0","Make","Model"],axis=1)

# %%
le=LabelEncoder()
X=X.apply(le.fit_transform)
xtrain,xtest,ytrain,ytest=train_test_split(X,Y,test_size=0.2,random_state=30)
rfr=RandomForestRegressor(criterion="mae",random_state=30)
model=rfr.fit(xtrain,ytrain)
pred=model.predict(xtest)
print("MAE is %.3f"%mean_absolute_error(ytest,pred))
# Out:
# MAE is 194.926
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   """

# %%
rfr=RandomForestRegressor(criterion="mae",random_state=30)
#n_estimators=number of tree
#max_depth=cut the trees from max_depth value

tp={"n_estimators":range(1,50,1),"max_depth":range(2,20,1)}
cv=GridSearchCV(rfr,tp,scoring="neg_mean_absolute_error",cv=4)
cvmodel=cv.fit(xtrain,ytrain)
ntress=cvmodel.best_params_["n_estimators"]
md=cvmodel.best_params_["max_depth"]
rfr=RandomForestRegressor(criterion="mae",random_state=30,max_depth=md,n_estimators=ntress) 
model=rfr.fit(xtrain,ytrain)
pred=model.predict(xtest)
print("MAE is %.3f"%mean_absolute_error(ytest,pred))
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:458: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:458: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:458: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# ...
